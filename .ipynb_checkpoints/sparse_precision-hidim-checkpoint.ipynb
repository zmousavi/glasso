# %%
print(__doc__)
# author: Gael Varoquaux <gael.varoquaux@inria.fr>
# License: BSD 3 clause
# Copyright: INRIA

import numpy as np
from scipy import linalg
from sklearn.datasets import make_sparse_spd_matrix
from sklearn.covariance import GraphicalLassoCV, graphical_lasso
import matplotlib.pyplot as plt

from sklearn.utils.extmath import fast_logdet

# %%
# #############################################################################
# Generate the data
n_samples = 60
n_features = 20

prng = np.random.RandomState(1)
prec = make_sparse_spd_matrix(n_features, alpha=.98,
                              smallest_coef=.4,
                              largest_coef=.7,
                              random_state=prng)
cov = linalg.inv(prec)
d = np.sqrt(np.diag(cov))
cov /= d
cov /= d[:, np.newaxis]
prec *= d
prec *= d[:, np.newaxis]
X = prng.multivariate_normal(np.zeros(n_features), cov, size=n_samples)
X -= X.mean(axis=0)
X /= X.std(axis=0)
# Out:
# Automatically created module for IPython interactive environment

# %%
#Empirical 
emp_cov = np.cov(X.T, bias=1)
emp_prec = linalg.inv(emp_cov)

# %%
# #############################################################################
# Estimate the covariance
emp_cov = np.dot(X.T, X) / n_samples

model = GraphicalLassoCV(cv=5)
model.fit(X)
cv_cov = model.covariance_
cv_prec = model.precision_

# plot the model selection metric
plt.figure(figsize=(4, 3))
plt.axes([.2, .15, .75, .7])
plt.plot(model.cv_alphas_, np.mean(model.grid_scores_, axis=1), 'o-')
plt.axvline(model.alpha_, color='.5')
plt.title('Model selection')
plt.ylabel('Cross-validation score')
plt.xlabel('alpha')

plt.show()

# %%
#BIC for different alpha 
alpha_array = model.cv_alphas_
bic = []
# delta_prec = []
for alpha in alpha_array:
    
    g = graphical_lasso(emp_cov, alpha, return_costs=True)

    prec_g = g[1]
    log_likelihood_g = - np.sum(emp_cov * prec_g) + fast_logdet(prec_g) 
    off_diag_nz = np.sum(np.triu(prec_g)) # sum upper off diag elements
    cost_g =  log_likelihood_g + 2* alpha * off_diag_nz
    bic.append( -2*log_likelihood_g + 1 *off_diag_nz * np.log(X.shape[0]))
#     delta_prec.append(np.linalg.norm(prec_g-prec))

#pick the smallest BIC
alpha_bic = alpha_array[np.argmin(bic)]
g_bic = graphical_lasso(emp_cov, alpha=alpha_bic)
bic_prec = g_bic[1]
bic_cov = g_bic[0]

# plot the model selection metric
plt.figure(figsize=(4, 3))
plt.axes([.2, .15, .75, .7])
plt.plot(model.cv_alphas_, bic, 'o-')
plt.axvline(alpha_bic, color='.5')
plt.title('Model selection')
plt.ylabel('BIC score')
plt.xlabel('alpha')

plt.show()

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.subplots_adjust(left=0.02, right=0.98)

# plot the covariances
covs = [('Empirical', emp_cov), ('BIC', bic_cov),
        ('GraphicalLassoCV', cv_cov), ('True', cov)]
vmax = cov_.max()
for i, (name, this_cov) in enumerate(covs):
    plt.subplot(2, 4, i + 1)
    plt.imshow(this_cov, interpolation='nearest', vmin=-vmax, vmax=vmax,
               cmap=plt.cm.RdBu_r)
    plt.xticks(())
    plt.yticks(())
    plt.title('%s covariance' % name)


# plot the precisions
precs = [('Empirical', emp_prec), ('BIC', bic_prec),
         ('GraphicalLasso', cv_prec), ('True', prec)]
vmax = .9 * prec_.max()
for i, (name, this_prec) in enumerate(precs):
    ax = plt.subplot(2, 4, i + 5)
    plt.imshow(np.ma.masked_equal(this_prec, 0),
               interpolation='nearest', vmin=-vmax, vmax=vmax,
               cmap=plt.cm.RdBu_r)
    plt.xticks(())
    plt.yticks(())
    plt.title('%s precision' % name)
    if hasattr(ax, 'set_facecolor'):
        ax.set_facecolor('.7')
    else:
        ax.set_axis_bgcolor('.7')

# %%
# Out:
# array([[ 1.11465453e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          1.15588819e-01, -0.00000000e+00,  0.00000000e+00,
#          1.39922363e-01, -2.99239578e-01,  0.00000000e+00,
#         -3.28423158e-03, -0.00000000e+00],
#        [-0.00000000e+00,  1.01488617e+00, -8.67063604e-02,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  4.40465063e-02,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -7.28546328e-02, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00],
#        [ 0.00000000e+00, -8.67063604e-02,  1.04364698e+00,
#         -1.46291133e-01, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -6.77733797e-02,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  1.72530145e-02,
#          1.09671515e-01,  5.71933713e-03, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00, -1.46291133e-01,
#          1.04156892e+00,  0.00000000e+00, -6.59183775e-02,
#         -0.00000000e+00,  9.22647844e-02,  0.00000000e+00,
#         -0.00000000e+00,  2.72391475e-02,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -2.67208156e-02, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -8.12361932e-02],
#        [ 0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  1.09569910e+00, -0.00000000e+00,
#          6.15878085e-02, -2.47922752e-01,  0.00000000e+00,
#         -0.00000000e+00, -4.41018766e-02, -0.00000000e+00,
#          1.59772687e-01,  0.00000000e+00, -1.04899827e-02,
#         -0.00000000e+00,  1.02948540e-02,  0.00000000e+00,
#         -7.25354477e-02, -0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -6.59183775e-02, -0.00000000e+00,  1.24098898e+00,
#         -7.30800492e-02, -4.19895421e-02,  2.80121086e-03,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -6.00153793e-02, -0.00000000e+00,  0.00000000e+00,
#         -4.90700102e-01, -0.00000000e+00, -5.92716435e-02,
#          1.49871970e-01, -0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  6.15878085e-02, -7.30800492e-02,
#          1.27459064e+00,  0.00000000e+00,  1.53719988e-02,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -1.31602502e-02,  0.00000000e+00,
#          0.00000000e+00, -5.79564498e-01, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00],
#        [ 0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          9.22647844e-02, -2.47922752e-01, -4.19895421e-02,
#          0.00000000e+00,  1.07472876e+00,  2.32447949e-02,
#          5.26908981e-03, -7.29206253e-02,  6.07806865e-04,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00],
#        [-0.00000000e+00,  4.40465063e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,